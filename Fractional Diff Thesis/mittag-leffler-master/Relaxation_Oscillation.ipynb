# %% [markdown]
# RELAXATION OSCILLATION FRACTIONAL DIFFERENTIAL EQUATIONS

# %%
import numpy as np 
from scipy.special import gamma, binom
from mittag_leffler import ml 
import time

# %%
class Relax_Osc: 
    """ 
    Initialize class given a dict "params" 
    """ 
    def __init__(self,params): 
        self.Acoeff = params["Acoeff"] 
        self.alpha  = params["alpha"] 
        self.f      = params["f"] 
        self.ICs    = params["ICs"] 
        self.m      = int(np.ceil(self.alpha)) 
        assert 0 < self.m <= 2, "ceil(alpha) must be 0 < ceil(alpha) <= 2" 
        assert self.m == len(self.ICs), "Must have ceil(alpha) number of initial conditions defined" 
        self.method  = params["method"]
        self.tmin    = params["tmin"] 
        self.tmax    = params["tmax"] 
        self.dt      = params["dt"] 
        self.tnum    = np.arange(self.tmin,self.tmax,self.dt) 
        self.ynum    = np.zeros(self.tnum.shape[0]) 
        self.wj = np.array([(-1)**j * binom(self.alpha,j) for j in range(len( self.tnum))])
        self.analytic = params["analytic"] 
        if self.analytic: 
            self.tanalytic = np.arange(self.tmin,self.tmax,(self.tmax-self. tmin)/1000.) 
            self.yanalytic = np.zeros(self.tanalytic.shape[0]) 
        self.exec_tanalyt = 0.; 
        self.exec_tnum = 0. 
        self.MAE = 0.; self.MSE = 0. 
        self.error = params["error"]
        self.write = params["write"]
    def analytical(self): 
        tanalyt0 = time.time() 
        A = self.Acoeff 
        start = min(self.tanalytic) 
        print("Analytical simulation size: %2d points" %self.tanalytic.shape [0]) 
        print("Evaluating analytical solution...") 
        # Define integrand for analytical solution 
        G2 = lambda t: t**(self.alpha-1) * ml(-A*t**self.alpha,self.alpha,self .alpha) 
        G2res = G2(self.tanalytic) 
        # Solve for analytical solution 
        f = self.f(self.tanalytic) 
        for i in range(1,len(self.tanalytic)): 
            self.yanalytic[i] = np.trapz(G2res[:i][::-1]*f[:i],self.tanalytic [:i]) 
        tanalyt1 = time.time() 
        self.exec_tanalyt = tanalyt1 - tanalyt0 
        print("DONE!") 
        return self.yanalytic
    
    
    def numerical(self): 
        tnum0 = time.time() 
        print("Numerical simulation size: %2d points" %self.tnum.shape[0]) 
        print("Evaluating numerical solution...") 
        T = len(self.tnum) 
        A = self.Acoeff 
        self.ynum[0] = self.ICs[0] 
        if self.m == 2: 
            self.ynum[1] = self.ICs[1] * self.dt + self.ynum[0] 
        if self.method == "GL": 
            for i in range(self.m,T): 
                term1 = A*self.dt**self.alpha * self.ynum[i-1] 
                term2 = np.dot(self.wj[1:i+1],self.ynum[i-1::-1]) # Main fractional derivative calculation 
                term3 = self.dt**self.alpha * self.f(self.tnum[i]) 
                self.ynum[i] = -term1 - term2 + term3 
        if self.method == "matrix": 
            from scipy.linalg import solve_triangular 
            # Generate LHS matrix 
            left = np.zeros((T-self.m,T-self.m)) 
            main_diag = np.diag_indices(T-self.m)
            # Lower triangular matrix with GL coefficients 
            for i in range(T-self.m): 
                left[i,:i+1] = self.wj[:i+1][::-1] 
            left *= self.dt**-self.alpha 
            left[main_diag] += A 
            # Generate RHS vector values 
            right = self.f(self.tnum[self.m:]) 
            # Solve for numerical solution 
            self.ynum[self.m:] = solve_triangular(left,right,lower=True, check_finite=True) 
        tnum1 = time.time() 
        self.exec_tnum = tnum1 - tnum0 
        print("DONE!") 
        return self.ynum
    def plot(self): 
        import matplotlib.pyplot as plt 
        plt.figure(figsize=(7,5)) 
        plt.plot(self.tnum,self.ynum,label="Numerical") 
        if self.analytic: 
            plt.plot(self.tanalytic,self.yanalytic,label="Analytical") 
        plt.xlabel("Time") 
        plt.ylabel("y(t)") 
        plt.title(r"Relaxation-Oscillation Model (h = %.3f)" %self.dt) 
        plt.xlim(min(self.tnum),max(self.tnum)) 
        plt.legend(loc=1) 
        plt.show() 
    def run(self): 
        self.get_params() 
        self.numerical() 
        print("Time to calculate numerical solution: %.6f" %self.exec_tnum) 
        print("--------")
        if self.analytic: 
            self.analytical() 
            print("Time to calculated analytical solution: %.6f" %self. exec_tanalyt) 
            if self.error: 
                self.get_error() 
                print("MAE: %.3e, MSE: %.3e" %(self.MAE,self.MSE)) 
        if (not self.analytic and self.error): 
            print("Cannot calculate error without analytical solution") 
        if self.write: 
            store_data = "RO_results_" + self.method + ".txt" 
            f = open(store_data,"a") 
            f.write("%.6f,%.6f,%.6f,%.6f,%.6e,%.6e\n" %(self.alpha,self.dt, self.exec_tnum,self.exec_tanalyt,self.MAE,self.MSE)) 
            f.close()
        print("================================================\n")
    def get_error(self): 
        """ 
        Since the number of points calculated for the analytical and numerical 
        solutions are not necessarily the same,
        we match the common time points of both analytical and numerical 
        solutions and average the error of all matched points. 
        """
        self.MAE = 0.; 
        self.MSE = 0. 
        dt_analyt = (self.tmax-self.tmin)/1000. # predetermined number of step size for analytical solution for sufficient resolution
        print("Calculating error...") 
        j = 0; count = 0  
        # Matching algorithm is faster if you for loop goes through fewer points!
        # Loop through analytical points and scan through numerical points only once for matches
        if dt_analyt >= self.dt:
            for i in range(len(self.tanalytic)):
                prev = j
                while not np.isclose(self.tnum[j], self.tanalytic[i]):
                    if self.tnum[j] > self.tanalytic[i] or j == len(self.tnum) -1:
                        j = prev
                        break
                    j += 1
                if j != prev:
                    self.MAE += np.abs(self.yanalytic[i] - self.ynum[j]) 
                    self.MSE += (self.yanalytic[i] - self.ynum[j])**2 
                    count += 1 

        # Loop through numerical points and scan through analytical points only once for matches
        if dt_analyt < self.dt:
            for i in range(len(self.tnum)):
                prev = j
                while not np.isclose(self.tnum[i], self.tanalytic[j]):
                    if self.tanalytic[j] > self.tnum[i] or j == len(self. tanalytic)-1:
                        j = prev
                        break
                    j += 1
                if j != prev:
                    self.MAE += np.abs(self.yanalytic[j] - self.ynum[i]) 
                    self.MSE += (self.yanalytic[j] - self.ynum[i])**2 
                    count += 1 
        # If no matches are made, set error to 0 to avoid divide by zero
        if count == 0:
            self.MAE = 0.; self.MSE = 0. 
        else: 
            self.MAE = self.MAE/count; self.MSE = self.MSE/count 
        print("DONE!")
        return self.MAE,self.MSE
    def output(self):
        return self.t, self.ynum, self.tanalytic, self.yanalytic
    def get_params(self):
        print("================================================")
        print("RELAXATION-OSCILLATION PROBLEM:")
        print("--------------------------------") 
        print("_0D_t^alpha y(t) + A*y(t) = f(t)") 
        print("--------------------------------") 
        print("PARAMS:") 
        print("alpha = %.2f" %self.alpha) 
        print("method = %s" %self.method) 
        print("t range = [%.2f,%2.f]" %(min(self.tnum),max(self.tnum))) 
        print(" y(0) = %.2f, y\'(0) = %.2f" %(self.ICs[0],self.ICs[1])) 
        print(" dt = %.3f" %self.dt)
if __name__ == "__main__":
    """
    _0D_t^alpha y(t) + Ay(t) = f(t)
     
    """   
    params = {
        "Acoeff"   : 0.5, # A coefficient 
        "alpha"    : 1.5, # alpha-order derivative 
        "f"        : lambda t : np.heaviside(t,0), # Use lambda function to define your source function 
        "tmin"     : 0, # Start time 
        "tmax"     : 10, # End time 
        "dt"       : 0.001, # Time step 
        "ICs"      : [0,0], # Define initial conditions, must satsify existence (ceil(alpha) = # initial conditions) 
        "method"   : "GL", # Pick numerical method, "GL" or "matrix" 
        "analytic" : True, # Solve for analytical solution? True or False 
        "error"    : True, # Evaluate both mean absolute error and mean square error (MAE and MSE) 
        "write"    : True # Write 6 values for: alpha, dt, numerical comp time, analytical comp time, MAE, MSE 
    }
    # How to initialize class and run code 
    # RO = Relax_Osc(params) 
    # RO.run() 
    # RO.plot() 
    # t,ynum,tanalytic,yanalytic = RO.output() 
    # How to do multiple runs 
    step = np.arange(0.001,0.011,0.001) 
    step = np.concatenate((step,np.arange(0.02,0.11,0.01))) 
    step = np.concatenate((step,np.arange(0.2,1.1,0.1))) 
    iterations = 1 
    for h in step:
        params["dt"] = h 
        RO = Relax_Osc(params) 
        for i in range(iterations): 
            RO.run() 
            RO.plot()
# Out:
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.001
# Numerical simulation size: 10000 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.222008
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.563992
# Calculating error...
# DONE!
# MAE: 4.694e-03, MSE: 4.172e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.002
# Numerical simulation size: 5000 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.105996
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.730005
# Calculating error...
# DONE!
# MAE: 4.533e-03, MSE: 3.851e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.003
# Numerical simulation size: 3334 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.069999
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.523000
# Calculating error...
# DONE!
# MAE: 4.375e-03, MSE: 3.546e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.004
# Numerical simulation size: 2500 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.056004
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.618003
# Calculating error...
# DONE!
# MAE: 4.223e-03, MSE: 3.259e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.005
# Numerical simulation size: 2000 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.046999
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.513994
# Calculating error...
# DONE!
# MAE: 4.065e-03, MSE: 2.980e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.006
# Numerical simulation size: 1667 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.037112
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.577985
# Calculating error...
# DONE!
# MAE: 3.916e-03, MSE: 2.720e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.007
# Numerical simulation size: 1429 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.027003
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.607994
# Calculating error...
# DONE!
# MAE: 3.784e-03, MSE: 2.488e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.008
# Numerical simulation size: 1250 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.020001
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.556995
# Calculating error...
# DONE!
# MAE: 3.635e-03, MSE: 2.253e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.009
# Numerical simulation size: 1112 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.021999
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.537003
# Calculating error...
# DONE!
# MAE: 3.484e-03, MSE: 2.032e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.010
# Numerical simulation size: 1000 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.018000
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.618000
# Calculating error...
# DONE!
# MAE: 3.350e-03, MSE: 1.833e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.020
# Numerical simulation size: 500 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.011005
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.765999
# Calculating error...
# DONE!
# MAE: 2.197e-03, MSE: 6.832e-06
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.030
# Numerical simulation size: 334 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.005999
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.642997
# Calculating error...
# DONE!
# MAE: 2.835e-03, MSE: 1.063e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.040
# Numerical simulation size: 251 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.007007
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.583002
# Calculating error...
# DONE!
# MAE: 4.510e-03, MSE: 2.987e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.050
# Numerical simulation size: 201 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.004003
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.693004
# Calculating error...
# DONE!
# MAE: 6.381e-03, MSE: 6.462e-05
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.060
# Numerical simulation size: 167 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.005002
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.678988
# Calculating error...
# DONE!
# MAE: 8.316e-03, MSE: 1.148e-04
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.070
# Numerical simulation size: 143 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.003001
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.584997
# Calculating error...
# DONE!
# MAE: 1.030e-02, MSE: 1.809e-04
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.080
# Numerical simulation size: 126 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.004002
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.560999
# Calculating error...
# DONE!
# MAE: 1.231e-02, MSE: 2.630e-04
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.090
# Numerical simulation size: 112 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.003007
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.552997
# Calculating error...
# DONE!
# MAE: 1.426e-02, MSE: 3.583e-04
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.100
# Numerical simulation size: 101 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.003005
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.703992
# Calculating error...
# DONE!
# MAE: 1.637e-02, MSE: 4.750e-04
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.200
# Numerical simulation size: 50 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.000999
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.648998
# Calculating error...
# DONE!
# MAE: 3.722e-02, MSE: 2.527e-03
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.300
# Numerical simulation size: 34 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.000997
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.705998
# Calculating error...
# DONE!
# MAE: 5.795e-02, MSE: 6.212e-03
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.400
# Numerical simulation size: 25 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.001008
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.539992
# Calculating error...
# DONE!
# MAE: 8.092e-02, MSE: 1.205e-02
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.500
# Numerical simulation size: 20 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.002007
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.826991
# Calculating error...
# DONE!
# MAE: 1.044e-01, MSE: 1.986e-02
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.600
# Numerical simulation size: 17 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.001000
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.672999
# Calculating error...
# DONE!
# MAE: 1.260e-01, MSE: 2.940e-02
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.700
# Numerical simulation size: 15 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.000999
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.549005
# Calculating error...
# DONE!
# MAE: 1.481e-01, MSE: 4.064e-02
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.800
# Numerical simulation size: 13 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.000996
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.651002
# Calculating error...
# DONE!
# MAE: 1.751e-01, MSE: 5.598e-02
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00,10]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 0.900
# Numerical simulation size: 12 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.000000
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.544003
# Calculating error...
# DONE!
# MAE: 1.921e-01, MSE: 7.123e-02
# ================================================
# ================================================
# RELAXATION-OSCILLATION PROBLEM:
# --------------------------------
# _0D_t^alpha y(t) + A*y(t) = f(t)
# --------------------------------
# PARAMS:
# alpha = 1.50
# method = GL
# t range = [0.00, 9]
#  y(0) = 0.00, y'(0) = 0.00
#  dt = 1.000
# Numerical simulation size: 10 points
# Evaluating numerical solution...
# DONE!
# Time to calculate numerical solution: 0.000998
# --------
# Analytical simulation size: 1000 points
# Evaluating analytical solution...
# DONE!
# Time to calculated analytical solution: 0.544002
# Calculating error...
# DONE!
# MAE: 2.351e-01, MSE: 9.943e-02
# ================================================
